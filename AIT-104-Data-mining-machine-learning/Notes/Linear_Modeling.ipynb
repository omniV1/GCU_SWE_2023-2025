# %% [markdown]
# # Introduction and Objective
#
# Linear models help us to understand and predict the behavior of complex systems. Linear models are foundational concepts and tools in machine learning, as they describe a response variable in terms of a linear combination of predictor variables.
#
# Check [Machine learning chapters 1-3](https://bibliu.com/app/?bibliuMagicToken=MPhcV5uN5lBQP6YceF7eEQyeTaZFXfii#/view/books/9781498738569/epub/OPS/xhtml/12_Chapter01.html#page_14)
#
# check [Python in Machine Learning: CH 1-3](https://ebookcentral-proquest-com.lopes.idm.oclc.org/lib/gcu/reader.action?docID=5747364&c=RVBVQg&ppg=1)
#
# see [Building Machine Learning with python: CH-1](https://ebookcentral-proquest-com.lopes.idm.oclc.org/lib/gcu/detail.action?docID=5485017)
#
# and the goals are:
# ---
# 1. Develop a linear model.
#
# 2. Evaluate the relationship between a set of attributes and a set of responses.
#
#
# 3. Calculate residuals to model the errors between the data and the proposed deterministic model.
#
#
# 4. Analyze investment decisions from a Christian worldview.
#
# # Data Description
#
# This section should include details about the data you will use, including its source, structure, and the kind of information it contains.
#
# # Data Preprocessing
#
# Describe the steps you will take to clean and prepare the data for analysis, such as handling missing values, normalizing data, or feature engineering.
#
# # Analytical Model Description
#
# Provide a detailed description of the analytical model you plan to use, including its theoretical basis and why it is suitable for this project.
#
# # The Architectural Model (Pipeline) Used
#
# Describe the pipeline of data processing, model application, and any post-processing steps you plan to use.
#
# # Model Implementation
#
# Here, you can describe the implementation of your model, including any specific libraries or tools used.
#
# # Assumptions Verification
#
# Discuss any assumptions made during the modeling process and how you will verify these assumptions.
#
# # Deployment
#
# Describe how the model will be deployed, including any platforms or technologies used.
#
# # Execution
#
# Include the code necessary to execute your model, along with detailed comments explaining each step of the process.
#
# # Results
#
# Present the results of your model's application, including any data output or visualizations.
#
# # Model Validation
#
# Discuss how you will validate your model, including any metrics or methods used to ensure its accuracy and reliability.
#
# # Analysis
#
# Provide an analysis of the results, including any insights gained and how they relate to your initial objectives.
#
# # Error Estimation
#
# Estimate the error of your model, discussing any potential sources of error and how they were addressed.
#
# # Model Improvement
#
# Suggest any potential improvements to your model, including alternative approaches or additional data that could be used.
#
# # Repeat Steps 9-14 as Necessary
#
# Explain that the process of execution, results analysis, validation, and improvement may need to be repeated to refine the model.
#
# # Final Conclusion
#
# Summarize the findings of your project, including any final conclusions and the potential impact of your work.
